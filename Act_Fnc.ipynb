# %% [markdown]
# <img src="images_DL/obilor_DS.png" alt="Mundy Obilor Jim" width="400" height="200" align="right">

# %% [markdown]
# # Activation functions used in neural networks

# %% [markdown]
# In artificial neural network, the activation function is a mathematical “gate” in between the input feeding the current neuron and its output going to the next layer. It can be as simple as a step function that turns the neuron output on and off, depending on a rule or threshold.

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Auxiliary functions

# %%
# the auxiliary function forming the diagram
def make_plot(x, f, df, name):
    plt.figure()
    plt.figure(figsize=(10,4))
    plt.title(name, fontsize=20, fontweight='bold')
    plt.xlabel('z', fontsize=15)
    plt.ylabel('Activation function value', fontsize=15)
    sns.set_style("whitegrid")
    plt.plot(x, f, label="f (z)")
    plt.plot(x, df, label="f '(z)")
    plt.legend(loc=4, prop={'size': 15}, frameon=True,shadow=True, facecolor="white", edgecolor="black")
    plt.savefig(name + ".png")
    plt.show()

# %% [markdown]
# ### Sigmoid

# %%
# %%latex
# $$
# f(x)={\frac {1}{1+e^{-x}}}
# \hspace{1cm}
# f'(x) = f(x)\cdot(1-f(x))
# $$
# Out:
# $$
# f(x)={\frac {1}{1+e^{-x}}}
# \hspace{1cm}
# f'(x) = f(x)\cdot(1-f(x))
# $$

# %%
z = np.arange(-10, 10, 0.01)
f = 1/(1 + np.exp(-z))
df = f*(1 - f)
make_plot(z, f, df, "Sigmoid")

# %% [markdown]
# ### Tanh

# %%
# %%latex
# $$
#  f(x) = \operatorname {tgh} x={\frac {\sinh x}{\cosh x}}={\frac {e^{x}-e^{-x}}{e^{x}+e^{-x}}}
# \hspace{1cm}
# f'(x) = 1 - f(x)^{2}
# $$
# Out:
# $$
#  f(x) = \operatorname {tgh} x={\frac {\sinh x}{\cosh x}}={\frac {e^{x}-e^{-x}}{e^{x}+e^{-x}}}
# \hspace{1cm}
# f'(x) = 1 - f(x)^{2}
# $$

# %%
z = np.arange(-10, 10, 0.01)
f = np.tanh(z)
df = 1 - f*f
make_plot(z, f, df, "tanh")

# %% [markdown]
# ### ReLU
# 1. It’s cheap to compute as there is no complicated math. The model can therefore take less time to train or run.
#
# 2. It converges faster. Linearity means that the slope doesn’t plateau, or “saturate,” when x gets large. It doesn’t have the vanishing gradient problem suffered by other activation functions like sigmoid or tanh.
#
# 3. It’s sparsely activated. Since ReLU is zero for all negative inputs, it’s likely for any given unit to not activate at all. This is often desirable (see below).

# %%
# %%latex
# $$
# {\displaystyle f(x) = \begin{cases}
# 0 & \text{ if } x<0 \\
# x & \text{ if } x\geq x
# \end{cases}}
# \hspace{1cm}
# {\displaystyle f(x) = \begin{cases}
# 0 & \text{ if } x<0 \\
# 1 & \text{ if } x\geq x
# \end{cases}}$$
# Out:
# $$
# {\displaystyle f(x) = \begin{cases}
# 0 & \text{ if } x<0 \\
# x & \text{ if } x\geq x
# \end{cases}}
# \hspace{1cm}
# {\displaystyle f(x) = \begin{cases}
# 0 & \text{ if } x<0 \\
# 1 & \text{ if } x\geq x
# \end{cases}}$$

# %%
z = np.arange(-10, 10, 0.01)
f = z * (z > 0)
df = 1. * (z > 0)
make_plot(z, f, df, "ReLU")

# %% [markdown]
# ### Leaky ReLU

# %%
# %%latex
# $${\displaystyle f(x) = \begin{cases}
# 0.01 \cdot x & \text{ if } x<0 \\
# x & \text{ if } x\geq x
# \end{cases}}
# \hspace{1cm}
# {\displaystyle f(x) = \begin{cases}
# 0.01 & \text{ if } x<0 \\
# 1 & \text{ if } x\geq x
# \end{cases}}$$
# Out:
# $${\displaystyle f(x) = \begin{cases}
# 0.01 \cdot x & \text{ if } x<0 \\
# x & \text{ if } x\geq x
# \end{cases}}
# \hspace{1cm}
# {\displaystyle f(x) = \begin{cases}
# 0.01 & \text{ if } x<0 \\
# 1 & \text{ if } x\geq x
# \end{cases}}$$

# %%
z = np.arange(-10, 10, 0.01)
f = np.where(z > 0, z, z * 0.01)
df = np.where(z > 0, 1, 0.01)
make_plot(z, f, df, "Leaky_ReLU")

# %% [markdown]
# ## Thank you
# ---
